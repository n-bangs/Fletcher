# %%
from pymongo import MongoClient

# %%
import json

# %%
client = MongoClient()

# %%
db = client.ratebeer_database

# %%
beers = db.unique_beers

# %%
beers.find().next()
# Out:
# {'_id': ObjectId('581aab45a1b5a73ed5058a8d'),
#  'content': {'abv': 'none',
#   'avg_score': 'none',
#   'brewery': 'none',
#   'calories_12_oz': 'none',
#   'description': 'Brewed exclusively for CASK Pub & Kitchen, London, U.K.',
#   'name': '\n\nEvil Twin Nymphomaniac APA\n\n',
#   'overall_rating': 'none',
#   'style': 'none'},
#  'urlid': '/beer/evil-twin-nymphomaniac-apa/189868/'}

# %%
beer_names = set()
for beer in beers.find():
    beer_names.add(beer['content']['name'])

# %%
beers.find()[10000]
# Out:
# {'_id': ObjectId('581cd387a1b5a74c7278f340'),
#  'content': {'abv': '7.2%',
#   'avg_score': 'none',
#   'brewery': 'Cigar City Brewing',
#   'calories_12_oz': '216',
#   'description': 'none',
#   'name': '\n\nCigar City Brewpub SheezNutz\n\n',
#   'overall_rating': 'none',
#   'style': 'Porter'},
#  'urlid': '/beer/cigar-city-brewpub-sheeznutz/456079/'}

# %%
beer_names = [b.split('\r')[0].strip().replace('\x92',"") for b in beer_names]

# %%
url_dict = {}

# %%
for beer in beers.find():
    beer_name = beer['content']['name'].split('\r')[0].strip().replace('\x92',"")
    #ratios = [fuzz.ratio(beer_name.lower(), b) for b in brewer_list]
    #brewer = brewer_list[ratios.index(max(ratios))]
    url_dict[beer['urlid']] = [beer['content']['brewery'],beer_name]
    # bad code needs to be fixed (also first 5 unique beers need to be replaced)
    #beers.update({'_id': beer['_id']}, { '$set' : {'content' : {'name' : beer_name, 'brewery' : brewer}}})
    
    #print(beer_name,brewer)

# %%
url_dict
# Out:
# {'/beer/thornbridge-made-north/272814/': ['Thornbridge',
#   'Thornbridge Made North'],
#  '/beer/beavertown-lemon-phantom-once-upon-a-tree-cider-blend/276633/': ['Beavertown',
#   'Beavertown Lemon Phantom (Once Upon a Tree Cider Blend)'],
#  '/beer/deschutes-maple-gold/97478/': ['Deschutes Brewery',
#   'Deschutes Maple Gold'],
#  '/beer/mikkeller-zummer-zitra-top/176474/': ['Mikkeller',
#   'Mikkeller Zummer Zitra Top'],
#  '/beer/lagunitas-ipa--05256/223529/': ['Lagunitas Brewing Company (Heineken)',
#   'Lagunitas IPA - 05256'],
#  '/beer/avery-altar-boy-port-barrel/106997/': ['Avery Brewing Company',
#   'Avery Altar Boy (Port Barrel)'],
#  '/beer/brewdog-abstrakt-ab19/374432/': ['BrewDog', 'BrewDog Abstrakt AB:19'],
#  '/beer/piels/15723/': ['Pabst Brewing Company', 'Piels'],
#  '/beer/ballast-point-dorado-double-ipa--lemon-lime/453879/': ['Ballast Point Brewing Company (Constellation)',
#   'Ballast Point Dorado Double IPA - Lemon & Lime'],
#  '/beer/the-bruery-carmen--pomegranate/154443/': ['The Bruery',
#   'The Bruery Carmen - Pomegranate'],
#  '/beer/de-molen-morellen-lambiek/94939/': ['Brouwerij de Molen',
#   'De Molen Morellen Lambiek'],
#  '/beer/cigar-city-marshal-zhukovs-imperial-stout--double-barrel-aged-2010/126973/': ['Cigar City Brewing',
#   'Cigar City Marshal Zhukovs Imperial Stout - Double Barrel-aged 2010'],
#  '/beer/sierra-nevada-beer-camp-024-europale/123572/': ['Sierra Nevada Brewing Company',
#   'Sierra Nevada Beer Camp 024: EuropAle'],
#  '/beer/thornbridge-handel/98193/': ['Thornbridge', 'Thornbridge Handel'],
#  '/beer/amager-yodas-full-brazilian/308532/': ['Amager Bryghus',
#   'Amager Yodas Full Brazilian'],
#  '/beer/cigar-city--7venth-sun-hannahpus-imperial-stout-2016/406793/': ['Cigar City Brewing',
#   'Cigar City / 7venth Sun Hannahpus Imperial Stout (2016)'],
#  '/beer/the-kernel-india-pale-ale-motueka-simcoe/300592/': ['The Kernel',
#   'The Kernel India Pale Ale Motueka Simcoe'],
#  '/beer/the-kernel-imperial-stout/134852/': ['The Kernel',
#   'The Kernel Imperial Stout'],
#  '/beer/stone-ipa--chinook-dry-hopped/173365/': ['Stone Brewing',
#   'Stone IPA - Chinook Dry Hopped'],
#  '/beer/against-the-grain-swaffle-bier/227822/': ['Against the Grain Brewery',
#   'Against the Grain Swaffle Bier'],
#  '/beer/wicked-weed-saison-xix-tamarind/233322/': ['Wicked Weed Brewing',
#   'Wicked Weed Saison XIX (Tamarind)'],
#  '/beer/hill-farmstead-friendship-and-reunion/208821/': ['Hill Farmstead Brewery',
#   'Hill Farmstead Friendship and Reunion'],
#  '/beer/amager-chocolate-spring/319159/': ['Amager Bryghus',
#   'Amager Chocolate Spring'],
#  '/beer/avery-lychee-prickley-pear-bad-karma/330020/': ['Avery Brewing Company',
#   'Avery Lychee & Prickley Pear Bad Karma'],
#  '/beer/modern-times-funky-universal-friend--pinot-noir/370886/': ['Modern Times Beer',
#   'Modern Times Funky Universal Friend - Pinot Noir'],
#  '/beer/brew-by-numbers-20-03-belgian-pale--crystal-tettnang/444652/': ['Brew By Numbers',
#   'Brew By Numbers 20/03 Belgian Pale - Crystal & Tettnang'],
#  '/beer/the-kernel-india-pale-ale-centennial-mosaic/313451/': ['The Kernel',
#   'The Kernel India Pale Ale Centennial Mosaic'],
#  '/beer/the-bruery-rauchbier/451587/': ['The Bruery', 'The Bruery Rauchbier'],
#  '/beer/omnipollo-fruit-tap-3-sour-apricot/382719/': ['Omnipollo',
#   'Omnipollo Fruit Tap 3 Sour Apricot'],
#  '/beer/cigar-city-pilot-series-whiskey-oak-barleywine/140526/': ['Cigar City Brewing',
#   'Cigar City Pilot Series Whiskey Oak Barleywine'],
#  '/beer/america/417872/': ['none', 'America'],
#  '/beer/emelisse-vanille-ice-cream-stout/449902/': ['Brouwerij Emelisse',
#   'Emelisse Vanille Ice Cream Stout'],
#  '/beer/buxton-moor-top/124312/': ['Buxton', 'Buxton Moor Top'],
#  '/beer/stone-ipa--chervil-savory-thyme-lavender/233509/': ['Stone Brewing',
#   'Stone IPA - Chervil, Savory, Thyme & Lavender'],
#  '/beer/amstel-lager/38/': ['Heineken Nederland', 'Amstel Lager'],
#  '/beer/siren-calypso-berliner-weisse--bourbon-ba-gooseberry/339700/': ['Siren',
#   'Siren Calypso Berliner Weisse - Bourbon BA Gooseberry'],
#  '/beer/against-the-grain-chaz-select/427247/': ['Against the Grain Brewery',
#   'Against the Grain Chaz Select'],
#  '/beer/brewdog-vagabond-pale-ale/304469/': ['BrewDog',
#   'BrewDog Vagabond Pale Ale'],
#  '/beer/stuft-pizza-barley-wine/16671/': ['Firestone Walker Brewing (Duvel Moortgat)',
#   'Stuft Pizza Barley Wine'],
#  '/beer/founders-imperial-stout/5933/': ['Founders Brewing Company',
#   'Founders Imperial Stout'],
#  '/beer/to-ol-amass-black-is-beautiful-oatmeal-stout/277185/': ['To Øl',
#   'To Øl Amass "Black Is Beautiful" Oatmeal Stout'],
#  '/beer/crooked-stave-progenitor/317109/': ['Crooked Stave',
#   'Crooked Stave Progenitor'],
#  '/beer/to-ol-primal-pils/259164/': ['none', 'To Øl Primal Pils'],
#  '/beer/cigar-city-first-account-stout/103511/': ['Cigar City Brewing',
#   'Cigar City First Account Stout'],
#  '/beer/three-floyds-amon-amarth-ragnarok/142709/': ['Three Floyds Brewing Company',
#   'Three Floyds Amon Amarth Ragnarök'],
#  '/beer/heineken-buckler-highlands/23944/': ['Heineken Nederland',
#   'Heineken Buckler Highlands'],
#  '/beer/mikkeller-saphir-wet-hop-pale-ale/189174/': ['Mikkeller',
#   'Mikkeller Saphir Wet Hop Pale Ale'],
#  '/beer/coors-light-summer-brew/259905/': ['Coors Brewing Company (MillerCoors)',
#   'Coors Light Summer Brew'],
#  '/beer/stone--dogfish-head--victory-saison-du-buff--red-wine-barrel/170283/': ['Stone Brewing',
#   'Stone / Dogfish Head / Victory Saison du BUFF - Red Wine Barrel'],
#  '/beer/deschutes-bravo-ipa/113868/': ['Deschutes Brewery',
#   'Deschutes Bravo IPA'],
#  '/beer/flying-dog-fever-dream-mango-habanero-ipa/400372/': ['Flying Dog Brewery',
#   'Flying Dog Fever Dream: Mango Habanero IPA'],
#  '/beer/mikkeller-weinbrand-un-barrel-aged-red-ale/122194/': ['Mikkeller',
#   'Mikkeller Weinbrand Un-barrel Aged Red Ale'],
#  '/beer/ballast-point--half-acre-rye-ipa/355961/': ['Ballast Point Brewing Company (Constellation)',
#   'Ballast Point / Half Acre Rye IPA'],
#  '/beer/the-kernel-pale-ale-citra-columbus/169656/': ['The Kernel',
#   'The Kernel Pale Ale Citra Columbus'],
#  '/beer/oskar-blues-donkey-tail/262056/': ['Oskar Blues Brewery',
#   'Oskar Blues Donkey Tail'],
#  '/beer/magic-rock-ot-rocks/214448/': ['none', 'Magic Rock OT Rocks'],
#  '/beer/cigar-city-warmer-winter-winter-warmer--coriander-aged/118370/': ['Cigar City Brewing',
#   'Cigar City Warmer Winter Winter Warmer - Coriander Aged'],
#  '/beer/emelisse-biertuig/408508/': ['Brouwerij Emelisse',
#   'Emelisse Biertuig'],
#  '/beer/cigar-city-jai-alai-ipa--kumquat-orange/140183/': ['Cigar City Brewing',
#   'Cigar City Jai Alai IPA - Kumquat Orange'],
#  '/beer/three-floyds-alpha-naught-2015/342671/': ['Three Floyds Brewing Company',
#   'Three Floyds Alpha Naught (2015)'],
#  '/beer/prairie-flare/371428/': ['Prairie Artisan Ales', 'Prairie Flare'],
#  '/beer/emelisse-imperial-russian-stout-laphroaig-ba/142363/': ['Brouwerij Emelisse',
#   'Emelisse Imperial Russian Stout (Laphroaig BA)'],
#  '/beer/bud-light-lime-mang-o-rita-6/283834/': ['Anheuser-Busch InBev',
#   'Bud Light Lime Mang-o-Rita (6%)'],
#  '/beer/brew-by-numbers-13-06-brett-aged-bourbon-barrel-aged-imperial-porter/368463/': ['Brew By Numbers',
#   'Brew By Numbers 13/06 Brett Aged Bourbon Barrel Aged Imperial Porter'],
#  '/beer/magic-rock--brewfist-ryperbole/314871/': ['Magic Rock Brewing',
#   'Magic Rock / Brewfist Ryperbole'],
#  '/beer/mikkeller-1000-ibu-light/143817/': ['none',
#   'Mikkeller 1000 IBU Light'],
#  '/beer/stone-sublimely-self-righteous-black-ipa--cocoa-mole-green-pepper/237767/': ['Stone Brewing',
#   'Stone Sublimely Self Righteous Black IPA - Cocoa, Mole & Green Pepper'],
#  '/beer/cigar-city-marshal-zhukovs-imperial-stout--coffee/364732/': ['Cigar City Brewing',
#   'Cigar City Marshal Zhukovs Imperial Stout - Coffee'],
#  '/beer/21st-amendment-two-lane-blacktop/117858/': ['21st Amendment Brewery',
#   '21st Amendment Two Lane Blacktop'],
#  '/beer/mikkeller-better-half/255895/': ['Mikkeller', 'Mikkeller Better Half'],
#  '/beer/wild-blue/51222/': ['Anheuser-Busch InBev', 'Wild Blue'],
#  '/beer/firestone-walker-double-barrel-ale-batch-1000/53339/': ['Firestone Walker Brewing (Duvel Moortgat)',
#   'Firestone Walker Double Barrel Ale Batch 1000'],
#  '/beer/crooked-stave-st-bretta-winter-happy-leaf-beet/256639/': ['Crooked Stave',
#   'Crooked Stave St. Bretta (Winter) (Happy Leaf Beet)'],
#  '/beer/de-molen-bitch-black-saison/261231/': ['Brouwerij de Molen',
#   'De Molen Bitch Black Saison'],
#  '/beer/avery-san-juan-sour/357065/': ['Avery Brewing Company',
#   'Avery San Juan Sour'],
#  '/beer/bells-lavender-saison/351571/': ['Bell\x92s Brewery',
#   'Bells Lavender Saison'],
#  '/beer/sierra-nevada-beer-camp-089-fistful-of-hops/200281/': ['Sierra Nevada Brewing Company',
#   'Sierra Nevada Beer Camp 089: Fistful of Hops'],
#  '/beer/sierra-nevada-audition-coffee-stout-w-lactose/384211/': ['Sierra Nevada Brewing Company',
#   'Sierra Nevada Audition Coffee Stout w/ Lactose'],
#  '/beer/ballast-point-little-india-pale-ale--spalt/241473/': ['Ballast Point Brewing Company (Constellation)',
#   'Ballast Point Little India Pale Ale - Spalt'],
#  '/beer/founders-solid-gold-extra-pale-ale/86244/': ['Founders Brewing Company',
#   'Founders Solid Gold Extra Pale Ale'],
#  '/beer/ballast-point-rd-this-ship-is-bananas/333420/': ['Ballast Point Brewing Company (Constellation)',
#   'Ballast Point R&D This Ship is Bananas'],
#  '/beer/cigar-city-tocobaga-lager/132267/': ['Cigar City Brewing',
#   'Cigar City Tocobaga Lager'],
#  '/beer/samuel-adams-ginger-snap-stout/203542/': ['Boston Beer Company',
#   'Samuel Adams Ginger Snap Stout'],
#  '/beer/dugges-provbrygd-1-2007--kalven/69608/': ['Dugges Bryggeri',
#   'Dugges Provbrygd 1-2007 - Kalven'],
#  '/beer/petes-broadway-brown/124365/': ['none', 'Petes Broadway Brown'],
#  '/beer/bruery-terreux-tart-of-darkness/145153/': ['Bruery Terreux',
#   'Bruery Terreux Tart of Darkness'],
#  '/beer/ballast-point-victory-at-sea--heaven-hill-bourbon-barrel/425073/': ['Ballast Point Brewing Company (Constellation)',
#   'Ballast Point Victory at Sea - Heaven Hill Bourbon Barrel'],
#  '/beer/evil-twin-molotov-cocktail/150395/': ['Evil Twin Brewing',
#   'Evil Twin Molotov Cocktail'],
#  '/beer/flying-dog-brewhouse-rarities-sriracha-pale-ale-pepper-mash/340640/': ['Flying Dog Brewery',
#   'Flying Dog Brewhouse Rarities: Sriracha Pale Ale (Pepper Mash)'],
#  '/beer/samuel-adams-the-vixen-chocolate-chili-bock/157431/': ['Boston Beer Company',
#   'Samuel Adams The Vixen Chocolate Chili Bock'],
#  '/beer/the-kernel-india-pale-ale-centennial-citra-simcoe/309246/': ['The Kernel',
#   'The Kernel India Pale Ale Centennial Citra Simcoe'],
#  '/beer/firestone-walker-feral-vinifera--component-sauvignon-blanc/350034/': ['Firestone Walker Brewing (Duvel Moortgat)',
#   'Firestone Walker Feral Vinifera - Component: Sauvignon Blanc'],
#  '/beer/the-bruery-loakal-red/131891/': ['The Bruery',
#   'The Bruery Loakal Red'],
#  '/beer/against-the-grain-snorhaar-biscuitje/238270/': ['Against the Grain Brewery',
#   'Against the Grain Snorhaar Biscuitje'],
#  '/beer/brewdog-avery-brown-dredge/141805/': ['BrewDog',
#   'BrewDog Avery Brown Dredge'],
#  '/beer/emelisse-white-label-aceto-balsamico-1-barrel-aged/229342/': ['Brouwerij Emelisse',
#   'Emelisse White Label Aceto Balsamico #1 Barrel Aged'],
#  '/beer/piels-light/11505/': ['Pabst Brewing Company', 'Piels Light'],
#  '/beer/the-bruery-praecocia/222808/': ['The Bruery', 'The Bruery Praecocia'],
#  '/beer/coors-non-alcoholic/8764/': ['Coors Brewing Company (MillerCoors)',
#   'Coors Non-Alcoholic'],
#  '/beer/founders-angelic-revenge/350968/': ['Founders Brewing Company',
#   'Founders Angelic Revenge'],
#  '/beer/de-molen-wikken-wegen/114116/': ['Brouwerij de Molen',
#   'De Molen Wikken & Wegen'],
#  '/beer/the-kernel-pale-ale-riwaka/148658/': ['The Kernel',
#   'The Kernel Pale Ale Riwaka'],
#  '/beer/jopen-de-hoop/241997/': ['Jopen', 'Jopen De Hoop'],
#  '/beer/mikkeller--green-flash-gron-blixt/434087/': ['Mikkeller',
#   'Mikkeller / Green Flash Grön Blixt'],
#  '/beer/siren-funky-feet/263651/': ['Siren', 'Siren Funky Feet'],
#  '/beer/chris-banker--insurgente--stone-xocoveza-mocha-stout--extra-anejo/352303/': ['Stone Brewing',
#   'Chris Banker / Insurgente / Stone Xocoveza Mocha Stout - Extra Añejo'],
#  '/beer/the-kernel-india-pale-ale-ella-citra-apollo-simcoe/287255/': ['The Kernel',
#   'The Kernel India Pale Ale Ella Citra Apollo Simcoe'],
#  '/beer/cigar-city-bobbys-bock/213499/': ['Cigar City Brewing',
#   'Cigar City Bobbys Bock'],
#  '/beer/the-kernel-export-stout-london-1864/454296/': ['The Kernel',
#   'The Kernel Export Stout London 1864'],
#  '/beer/wicked-weed-gaffel-esque-kolsch/301777/': ['Wicked Weed Brewing',
#   'Wicked Weed Gaffel-esque Kölsch'],
#  '/beer/oskar-blues-deviant-dales-blood-oranges/335316/': ['Oskar Blues Brewery',
#   'Oskar Blues Deviant Dales (Blood Oranges)'],
#  '/beer/to-ol-sur-galaxy/454915/': ['To Øl', 'To Øl Sur Galaxy'],
#  '/beer/avery-kentucky-bourbon-barrel/437009/': ['Avery Brewing Company',
#   'Avery Kentucky Bourbon Barrel'],
#  '/beer/flying-dog-imperial-ipa--nugget-single-hop/429284/': ['Flying Dog Brewery',
#   'Flying Dog Imperial IPA - Nugget Single Hop'],
#  '/beer/chris-banker--insurgente--stone-locoveza-extra-anejo/373120/': ['Stone Brewing',
#   'Chris Banker / Insurgente / Stone Locoveza Extra Añejo'],
#  '/beer/wicked-weed-el-paraiso-coffee-stout/243271/': ['Wicked Weed Brewing',
#   'Wicked Weed El Paraiso Coffee Stout'],
#  '/beer/emelisse-winterbier/98053/': ['Brouwerij Emelisse',
#   'Emelisse Winterbier'],
#  '/beer/sierra-nevada-sidecar-orange-pale-ale/447053/': ['Sierra Nevada Brewing Company',
#   'Sierra Nevada Sidecar Orange Pale Ale'],
#  '/beer/cigar-city-christmas-improvisacion/134157/': ['Cigar City Brewing',
#   'Cigar City Christmas Improvisación'],
#  '/beer/the-kernel-pale-ale-hallertau-blanc-galaxy/455703/': ['The Kernel',
#   'The Kernel Pale Ale Hallertau Blanc Galaxy'],
#  '/beer/founders-bourbon-apple-cream-ale/127840/': ['Founders Brewing Company',
#   'Founders Bourbon Apple Cream Ale'],
#  '/beer/siren-proteus--vol3-version-1--centennial-equinox-enigma/441337/': ['Siren',
#   'Siren Proteus - Vol.3 Version 1 - Centennial, Equinox, Enigma'],
#  '/beer/ballast-point-black-marlin-porter--bourbon-barrel/63825/': ['Ballast Point Brewing Company (Constellation)',
#   'Ballast Point Black Marlin Porter - Bourbon Barrel'],
#  '/beer/ballast-point-irish-breakfast/322434/': ['Ballast Point Brewing Company (Constellation)',
#   'Ballast Point Irish Breakfast'],
#  '/beer/cigar-city-prickly-pear-berliner-weisse/168453/': ['Cigar City Brewing',
#   'Cigar City Prickly Pear Berliner Weisse'],
#  '/beer/nogne-o-bitter/27898/': ['Nøgne Ø (Hansa Borg)', 'Nøgne Ø Bitter'],
#  '/beer/amager-amager-faelled/105587/': ['Amager Bryghus',
#   'Amager Amager Fælled'],
#  '/beer/21st-amendment-endeavour/147322/': ['21st Amendment Brewery',
#   '21st Amendment Endeavour'],
#  '/beer/firestone-walker-17-xvii-seventeenth-anniversary-ale/236504/': ['Firestone Walker Brewing (Duvel Moortgat)',
#   'Firestone Walker 17 (XVII Seventeenth Anniversary Ale)'],
#  '/beer/samuel-adams-longshot-chocolate-chili-bock/131743/': ['Boston Beer Company',
#   'Samuel Adams LongShot Chocolate Chili Bock'],
#  '/beer/brewdog-eurotrash/113321/': ['BrewDog', 'BrewDog Eurotrash'],
#  '/beer/de-molen-hout-hop-dryhopped/186552/': ['Brouwerij de Molen',
#   'De Molen Hout & Hop Dryhopped'],
#  '/beer/brewdog-dog-a/172237/': ['BrewDog', 'BrewDog Dog A'],
#  '/beer/pinta-grodziskie-50/432278/': ['Browar PINTA', 'Pinta Grodziskie 5.0'],
#  '/beer/mikkeller-spontanelderflower/229014/': ['none',
#   'Mikkeller SpontanElderflower'],
#  '/beer/new-belgium--verboten-top-bunk-bottom-bunk/325420/': ['New Belgium Brewing Company',
#   'New Belgium / Verboten Top Bunk Bottom Bunk'],
#  '/beer/coors-winterfest/2467/': ['Coors Brewing Company (MillerCoors)',
#   'Coors Winterfest'],
#  '/beer/avery-3point5-pale-ale/211386/': ['none', 'Avery 3Point5 Pale Ale'],
#  '/beer/amager-the-days-of-barley-and-roses/211605/': ['Amager Bryghus',
#   'Amager The Days Of Barley And Roses'],
#  '/beer/mikkeller-amarillo-ipa/55597/': ['none', 'Mikkeller Amarillo IPA'],
#  '/beer/fortuna-komes-belgian-ipa/449123/': ['Browar Fortuna',
#   'Fortuna Komes Belgian IPA'],
#  '/beer/flying-dog-kujo--elderberries/161195/': ['Flying Dog Brewery',
#   'Flying Dog Kujo - Elderberries'],
#  '/beer/evil-twin-pappys-imperial-biscotti-break/348220/': ['Evil Twin Brewing',
#   'Evil Twin Pappys Imperial Biscotti Break'],
#  '/beer/jopen-houten-haarlemmer-3/252972/': ['Jopen',
#   'Jopen Houten Haarlemmer #3'],
#  '/beer/cigar-city-improv/157999/': ['none', 'Cigar City Improv'],
#  '/beer/trillium-pot-kettle--barrel-aged/249932/': ['Trillium Brewing Company',
#   'Trillium Pot & Kettle - Barrel Aged'],
#  '/beer/emelisse-imperial-doppelbock/130105/': ['Brouwerij Emelisse',
#   'Emelisse Imperial Doppelbock'],
#  '/beer/to-ol-snowball-saison-aged-in-white-wine-barrels/204851/': ['To Øl',
#   'To Øl Snowball Saison (Aged in White Wine Barrels)'],
#  '/beer/founders-nitro-pale-ale/260971/': ['none', 'Founders Nitro Pale Ale'],
#  '/beer/thornbridge-the-light/122238/': ['Thornbridge',
#   'Thornbridge The Light'],
#  '/beer/the-kernel-pale-ale-hallertau-blanc/416576/': ['The Kernel',
#   'The Kernel Pale Ale Hallertau Blanc'],
#  '/beer/wieckse-witte/8148/': ['Heineken Nederland', 'Wieckse Witte'],
#  '/beer/amstel-zero/74956/': ['Heineken Nederland', 'Amstel Zero'],
#  '/beer/omnipollo-house-blend-nook/426637/': ['Omnipollo',
#   'Omnipollo House Blend #Nook'],
#  '/beer/the-bruery-mead-lange/102809/': ['The Bruery',
#   'The Bruery Mead-Lange'],
#  '/beer/cigar-city-florida-cracker--raspberry-jalapeno/345469/': ['Cigar City Brewing',
#   'Cigar City Florida Cracker - Raspberry & Jalapeño'],
#  '/beer/stillwater-barrel-aged-series--autumnal/155775/': ['Stillwater Artisanal',
#   'Stillwater Barrel Aged Series - Autumnal'],
#  '/beer/de-molen-svea-ipa/176098/': ['Brouwerij de Molen',
#   'De Molen Svea IPA'],
#  '/beer/cloudwater-winter-range--esb/381702/': ['Cloudwater Brew Co',
#   'Cloudwater Winter Range - ESB'],
#  '/beer/de-molen-groot-sterk/314285/': ['Brouwerij de Molen',
#   'De Molen Groot & Sterk'],
#  '/beer/cigar-city-auld-alliance/154028/': ['Cigar City Brewing',
#   'Cigar City Auld Alliance'],
#  '/beer/the-kernel-pale-ale-summit-galaxy-nzc/163950/': ['The Kernel',
#   'The Kernel Pale Ale Summit Galaxy NZC'],
#  '/beer/thornbridge-coconut-swan/122046/': ['Thornbridge',
#   'Thornbridge Coconut Swan'],
#  '/beer/against-the-grain-the-green-dragon/205477/': ['Against the Grain Brewery',
#   'Against the Grain The Green Dragon'],
#  '/beer/flying-dog-snake-dog-ipa-chipotle-peppers-lime-peel/379491/': ['Flying Dog Brewery',
#   'Flying Dog Snake Dog IPA (Chipotle Peppers & Lime Peel)'],
#  '/beer/mikkeller-vikings-return/94956/': ['Mikkeller',
#   'Mikkeller Vikings Return'],
#  '/beer/new-belgium-loves-leopold--pomegranate-blend/258325/': ['New Belgium Brewing Company',
#   'New Belgium Loves Leopold - Pomegranate Blend'],
#  '/beer/brew-by-numbers-15-03-black-ipa--mosaic/368794/': ['Brew By Numbers',
#   'Brew By Numbers 15/03 Black IPA - Mosaic'],
#  '/beer/avery-grapes-of-wrath/175665/': ['Avery Brewing Company',
#   'Avery Grapes of Wrath'],
#  '/beer/mikkeller-simcoe-hopped-india-pale-ale/329142/': ['Mikkeller',
#   'Mikkeller Simcoe Hopped India Pale Ale'],
#  '/beer/ballast-point-black-marlin-porter--bourbon-barrel-tart-cherries/236469/': ['Ballast Point Brewing Company (Constellation)',
#   'Ballast Point Black Marlin Porter - Bourbon Barrel: Tart Cherries'],
#  '/beer/cigar-city-jolly-guava-grove/119371/': ['Cigar City Brewing',
#   'Cigar City Jolly Guava Grove'],
#  '/beer/cigar-city-brewpub-cold-moon-flanders/246142/': ['Cigar City Brewing',
#   'Cigar City Brewpub Cold Moon Flanders'],
#  '/beer/de-molen--alvinne--haand--loverbeer-esb-sour-ale/214928/': ['Brouwerij de Molen',
#   'De Molen / Alvinne / Haand / LoverBeer ESB Sour Ale'],
#  '/beer/cigar-city-chocolate-raspberry-brown-ale/217462/': ['Cigar City Brewing',
#   'Cigar City Chocolate Raspberry Brown Ale'],
#  '/beer/thornbridge-spin-black-pale/367599/': ['Thornbridge',
#   'Thornbridge Spin Black Pale'],
#  '/beer/deschutes-black-pearl-ale/97477/': ['Deschutes Brewery',
#   'Deschutes Black Pearl Ale'],
#  '/beer/new-belgium-lips-of-faith--chads-blackberry-ale/71736/': ['New Belgium Brewing Company',
#   'New Belgium Lips of Faith - Chads Blackberry Ale'],
#  '/beer/founders-hop-wampa/422342/': ['Founders Brewing Company',
#   'Founders Hop Wampa'],
#  '/beer/winters-bourbon-cask-ale/54136/': ['Anheuser-Busch InBev',
#   'Winters Bourbon Cask Ale'],
#  '/beer/buxton-stronge-extra-stout/228988/': ['Buxton',
#   'Buxton Stronge Extra Stout'],
#  '/beer/sierra-nevada--ballast-point-beer-camp-electric-ray/263170/': ['Sierra Nevada Brewing Company',
#   'Sierra Nevada / Ballast Point Beer Camp Electric Ray'],
#  '/beer/avery-barrel-aged-series-10--muscat-damour/159971/': ['Avery Brewing Company',
#   'Avery Barrel-Aged Series 10 - Muscat dAmour'],
#  '/beer/brew-by-numbers-01-10-saison--classic/272710/': ['Brew By Numbers',
#   'Brew By Numbers 01/10 Saison - Classic'],
#  '/beer/the-bruery-smoking-wood--chipotle/202727/': ['The Bruery',
#   'The Bruery Smoking Wood - Chipotle'],
#  '/beer/brewdog-blitz/457719/': ['BrewDog', 'BrewDog Blitz'],
#  '/beer/thornbridge-wallonia/188481/': ['Thornbridge', 'Thornbridge Wallonia'],
#  '/beer/ballast-point-sextant-oatmeal-stout/273261/': ['Ballast Point Brewing Company (Constellation)',
#   'Ballast Point Sextant Oatmeal Stout'],
#  '/beer/evil-twin-bozo-beer/240069/': ['Evil Twin Brewing',
#   'Evil Twin Bozo Beer'],
#  '/beer/wicked-weed-dark-age-bourbon-stout/198126/': ['Wicked Weed Brewing',
#   'Wicked Weed Dark Age Bourbon Stout'],
#  '/beer/thornbridge-sensoria-ii/102696/': ['none', 'Thornbridge Sensoria II'],
#  '/beer/de-molen-hot-spicy-4-madame-jeanette/363604/': ['none',
#   'De Molen Hot & Spicy 4 (Madame Jeanette)'],
#  '/beer/to-ol-tabloid-beer/428946/': ['To Øl', 'To Øl Tabloid Beer'],
#  '/beer/bruery-terreux-melange-1/388535/': ['Bruery Terreux',
#   'Bruery Terreux Melange #1'],
#  '/beer/stone-pilot-series-dry-rub-ipa/451048/': ['Stone Brewing',
#   'Stone Pilot Series: Dry-Rub IPA'],
#  '/beer/thornbridge-pivni/155163/': ['Thornbridge', 'Thornbridge Pivní'],
#  '/beer/stone-spotlight-series-team-sea-cows-shot-in-the-dark/389729/': ['Stone Brewing',
#   'Stone Spotlight Series: Team Sea Cows Shot in the Dark'],
#  '/beer/lagunitas-cruising-with-ruben-and-the-bretts/114568/': ['Lagunitas Brewing Company (Heineken)',
#   'Lagunitas Cruising With Ruben and the Bretts'],
#  '/beer/brewdog-paradox-macallan-batch-011/89834/': ['BrewDog',
#   'BrewDog Paradox Macallan (Batch 011)'],
#  '/beer/the-bruery-2-turtle-doves/111485/': ['The Bruery',
#   'The Bruery 2 Turtle Doves'],
#  '/beer/jopen-houten-haarlemmer-2/190388/': ['Jopen',
#   'Jopen Houten Haarlemmer #2'],
#  '/beer/brewdog-bd-nottingham-01/244877/': ['BrewDog',
#   'BrewDog BD Nottingham 01'],
#  '/beer/against-the-grain-monster-bait/276441/': ['Against the Grain Brewery',
#   'Against the Grain Monster Bait'],
#  '/beer/prairie-you-so-crazy/293928/': ['Prairie Artisan Ales',
#   'Prairie You So Crazy'],
#  '/beer/brew-by-numbers-01-11-saison--quince/299001/': ['Brew By Numbers',
#   'Brew By Numbers 01/11 Saison - Quince'],
#  '/beer/brewdog-dead-pony-club-pale-ale/172207/': ['BrewDog',
#   'BrewDog Dead Pony (Club) Pale Ale'],
#  '/beer/three-floyds--warpigs-lazurite/402055/': ['Three Floyds Brewing Company',
#   'Three Floyds / Warpigs Lazurite'],
#  '/beer/bells-raspberry-ale/18547/': ['Bell\x92s Brewery',
#   'Bells Raspberry Ale'],
#  '/beer/avery-eremita-iv/184033/': ['Avery Brewing Company',
#   'Avery Eremita IV'],
#  '/beer/ac-golden-checkpoint-charlie-berliner-weisse/216421/': ['Coors Brewing Company (MillerCoors)',
#   'AC Golden Checkpoint Charlie Berliner Weisse'],
#  '/beer/mikkeller-beer-geek-breakfast-high-icu-peel-edition/172933/': ['Mikkeller',
#   'Mikkeller Beer Geek Breakfast (High ICU Peel Edition)'],
#  '/beer/ballast-point-cookie-monster/254156/': ['Ballast Point Brewing Company (Constellation)',
#   'Ballast Point Cookie Monster'],
#  '/beer/sierra-nevada-pina-de-la-noche/409492/': ['Sierra Nevada Brewing Company',
#   'Sierra Nevada Piña de la Noche'],
#  '/beer/beavertown-tiago-falcone/308677/': ['none',
#   'Beavertown Tiago Falcone'],
#  '/beer/royal-club-80/102801/': ['Heineken Nederland', 'Royal Club 8.0'],
#  '/beer/stone-spotlight-series-team-philly-whisperers-50-year-storm-west-coast-belgian/319767/': ['Stone Brewing',
#   'Stone Spotlight Series: Team Philly Whisperers 50-Year Storm West Coast Belgian'],
#  '/beer/thornbridge-mocha-porter/203703/': ['Thornbridge',
#   'Thornbridge Mocha Porter'],
#  '/beer/deschutes-the-abyss--pinot-noir/397429/': ['Deschutes Brewery',
#   'Deschutes The Abyss - Pinot Noir'],
#  '/beer/21st-amendment-563-stout/14938/': ['21st Amendment Brewery',
#   '21st Amendment 563 Stout'],
#  '/beer/wicked-weed-pick-me-dicks-pick/307790/': ['Wicked Weed Brewing',
#   'Wicked Weed Pick Me! Dicks Pick'],
#  '/beer/cigar-city-chaveta-india-dark-mild/103846/': ['Cigar City Brewing',
#   'Cigar City Chaveta India Dark Mild'],
#  '/beer/the-bruery-peanut-butter--bals/159300/': ['The Bruery',
#   'The Bruery Peanut Butter & -BALs'],
#  '/beer/mikkeller-exotic-punch/143895/': ['Mikkeller',
#   'Mikkeller Exotic Punch'],
#  '/beer/lagunitas-new-dogtown-pale-ale/86876/': ['Lagunitas Brewing Company (Heineken)',
#   'Lagunitas New DogTown Pale Ale'],
#  '/beer/buxton-wyns-tor/146159/': ['none', 'Buxton Wyns Tor'],
#  '/beer/dugges-provbrygd-1-2008--amarillo-brillo/91909/': ['Dugges Bryggeri',
#   'Dugges Provbrygd 1-2008 - Amarillo Brillo'],
#  '/beer/new-belgium-liquid-center-surprise--american-ipa/350996/': ['New Belgium Brewing Company',
#   'New Belgium Liquid Center Surprise - American IPA'],
#  '/beer/trillium--evil-twin-from-dusk-trill-dawn/428212/': ['Trillium Brewing Company',
#   'Trillium / Evil Twin From Dusk Trill Dawn'],
#  '/beer/cloudwater-spring-summer-2016-session-ipa-centennial-el-dorado/456337/': ['Cloudwater Brew Co',
#   'Cloudwater Spring Summer 2016 Session IPA Centennial El Dorado'],
#  '/beer/brew-by-numbers-17-05-table-saison--lemon-black-pepper/430524/': ['Brew By Numbers',
#   'Brew By Numbers 17/05 Table Saison - Lemon & Black Pepper'],
#  '/beer/oskar-blues-fall-diddy/243687/': ['Oskar Blues Brewery',
#   'Oskar Blues Fall Diddy'],
#  '/beer/budweiser-project-twelve--batch-0541-baldwinsville/195278/': ['Anheuser-Busch InBev',
#   'Budweiser Project Twelve - Batch 0541 (Baldwinsville)'],
#  '/beer/de-molen-open-bloot/225235/': ['Brouwerij de Molen',
#   'De Molen Open & Bloot'],
#  '/beer/amager--three-floyds-swole-mole/430606/': ['Amager Bryghus',
#   'Amager / Three Floyds Swole Mole'],
#  '/beer/mikkeller-beer-geek-brunch-weasel-islay-edition/109724/': ['Mikkeller',
#   'Mikkeller Beer Geek Brunch Weasel (Islay Edition)'],
#  '/beer/amager--stillwater-darkest-of-suns/377862/': ['Amager Bryghus',
#   'Amager / Stillwater Darkest of Suns'],
#  '/beer/samuel-adams-utopias/12228/': ['Boston Beer Company',
#   'Samuel Adams Utopias'],
#  '/beer/dugges-easy-christmas/190021/': ['Dugges Bryggeri',
#   'Dugges Easy Christmas'],
#  '/beer/brewdog-raspberry-revolver/193135/': ['BrewDog',
#   'BrewDog Raspberry Revolver'],
#  '/beer/sierra-nevada-belgian-blonde-ipa/209569/': ['Sierra Nevada Brewing Company',
#   'Sierra Nevada Belgian Blonde IPA'],
#  '/beer/sierra-nevada-ovila-quad--plums-madeira-barrel-aged/323959/': ['Sierra Nevada Brewing Company',
#   'Sierra Nevada Ovila Quad - Plums (Madeira Barrel Aged)'],
#  '/beer/stone-spotlight-series-team-livin-large-belgian-strong-ale/264196/': ['none',
#   'Stone Spotlight Series: Team Livin Large Belgian Strong Ale'],
#  '/beer/stone-old-guardian--oak-smoked-bourbon-barrel-aged/421971/': ['Stone Brewing',
#   'Stone Old Guardian - Oak Smoked: Bourbon Barrel Aged'],
#  '/beer/fortuna-mirabelka/254077/': ['Browar Fortuna', 'Fortuna Mirabelka'],
#  '/beer/modern-times-infinity-beach/405987/': ['Modern Times Beer',
#   'Modern Times Infinity Beach'],
#  '/beer/amager-honeyquad/230313/': ['Amager Bryghus', 'Amager HoneyQuad'],
#  '/beer/siren-proteus--vol2--mosaic-chinook-cascade/414860/': ['Siren',
#   'Siren Proteus - Vol.2 - Mosaic, Chinook, Cascade'],
#  '/beer/new-belgium-pumpkick/221467/': ['New Belgium Brewing Company',
#   'New Belgium Pumpkick'],
#  '/beer/the-kernel-pale-ale-cascade-chinook-citra/262907/': ['The Kernel',
#   'The Kernel Pale Ale Cascade Chinook Citra'],
#  '/beer/against-the-grain-ledersmoken/155856/': ['Against the Grain Brewery',
#   'Against the Grain Ledersmoken'],
#  '/beer/the-bruery-sucre-tawny-port-barrel/265171/': ['The Bruery',
#   'The Bruery Sucré (Tawny Port Barrel)'],
#  '/beer/sonnys-red-ale/190907/': ['Anheuser-Busch InBev', 'Sonnys Red Ale'],
#  '/beer/mikkeller-spontanlemon/436983/': ['Mikkeller',
#   'Mikkeller Spontanlemon'],
#  '/beer/brewdog-dog-e/411016/': ['none', 'BrewDog Dog E'],
#  '/beer/thornbridge-medici/261063/': ['Thornbridge', 'Thornbridge Medici'],
#  '/beer/dugges-almost-imperial/295333/': ['Dugges Bryggeri',
#   'Dugges Almost Imperial'],
#  '/beer/crooked-stave-lbrett-dor-dry-hopped/199809/': ['none',
#   'Crooked Stave LBrett dOr (Dry Hopped)'],
#  '/beer/cigar-city-florida-cracker--strawberry-jalapeno/311669/': ['Cigar City Brewing',
#   'Cigar City Florida Cracker - Strawberry & Jalapeño'],
#  '/beer/new-belgium-spring-blonde/246067/': ['New Belgium Brewing Company',
#   'New Belgium Spring Blonde'],
#  '/beer/the-bruery-fubrue/214559/': ['The Bruery', 'The Bruery FUBRue'],
#  '/beer/brewdog-paradox-islay-15/428220/': ['BrewDog',
#   'BrewDog Paradox Islay (15%)'],
#  '/beer/sierra-nevada-beer-camp-long-stem-ipa/153118/': ['none',
#   'Sierra Nevada Beer Camp Long Stem IPA'],
#  '/beer/the-bruery-pharaoh/147848/': ['The Bruery', 'The Bruery Pharaoh'],
#  '/beer/21st-amendment-saison/176780/': ['none', '21st Amendment Saison'],
#  '/beer/new-belgium-oscar-worthy-coffee/216436/': ['New Belgium Brewing Company',
#   'New Belgium Oscar Worthy Coffee'],
#  '/beer/prairie-mosaic-kisses/389207/': ['Prairie Artisan Ales',
#   'Prairie Mosaic Kisses'],
#  '/beer/dugges-sur-i-hatten/423420/': ['Dugges Bryggeri',
#   'Dugges Sur I Hatten'],
#  '/beer/cloudwater-pale/321401/': ['Cloudwater Brew Co', 'Cloudwater Pale'],
#  '/beer/jopen-burgemeesterbier/448153/': ['Jopen', 'Jopen Burgemeesterbier'],
#  '/beer/flying-dog-heat-series-carolina-reaper-peach-ipa/441346/': ['Flying Dog Brewery',
#   'Flying Dog Heat Series: Carolina Reaper Peach IPA'],
#  '/beer/de-molen-bed-breakfast/152323/': ['Brouwerij de Molen',
#   'De Molen Bed & Breakfast'],
#  '/beer/brew-by-numbers-16-05-red-ale--equinox/373058/': ['Brew By Numbers',
#   'Brew By Numbers 16/05 Red Ale - Equinox'],
#  '/beer/mikkeller-beer-geek-breakfast-107-bourbon-edition/118988/': ['Mikkeller',
#   'Mikkeller Beer Geek Breakfast 10.7% (Bourbon Edition)'],
#  '/beer/thornbridge-kmf/376560/': ['Thornbridge', 'Thornbridge KMF'],
#  '/beer/trillium-pm-dawn--barreiro/306583/': ['Trillium Brewing Company',
#   'Trillium PM Dawn - Barreiro'],
#  '/beer/lagunitas-fusion-iii/130823/': ['Lagunitas Brewing Company (Heineken)',
#   'Lagunitas Fusion III'],
#  '/beer/founders-backstage-series-2-cbs-canadian-breakfast-stout/98973/': ['Founders Brewing Company',
#   'Founders Backstage Series # 2: CBS (Canadian Breakfast Stout)'],
#  '/beer/modern-times-universal-friend--oaked-chardonnay/299254/': ['Modern Times Beer',
#   'Modern Times Universal Friend - Oaked Chardonnay'],
#  '/beer/omnipollo-perikles/321406/': ['Omnipollo', 'Omnipollo Perikles'],
#  '/beer/magic-rock-inhaler/402180/': ['Magic Rock Brewing',
#   'Magic Rock Inhaler'],
#  '/beer/amager-bryggens-blond/88087/': ['Amager Bryghus',
#   'Amager Bryggens Blond'],
#  '/beer/brewski--18th-street-nightmare-on-18th-street/426389/': ['Brewski',
#   'Brewski / 18th Street Nightmare On 18th Street'],
#  '/beer/dugges-blabarliner/282556/': ['Dugges Bryggeri', 'Dugges Blåbärliner'],
#  '/beer/flying-dog-pearl-necklace-oyster-stout-chocolate-mint/221884/': ['Flying Dog Brewery',
#   'Flying Dog Pearl Necklace Oyster Stout (Chocolate Mint)'],
#  '/beer/keystone-premium/2333/': ['Coors Brewing Company (MillerCoors)',
#   'Keystone Premium'],
#  '/beer/sierra-nevada-beer-camp-simmer-down-brown/200375/': ['Sierra Nevada Brewing Company',
#   'Sierra Nevada Beer Camp Simmer Down Brown'],
#  '/beer/evil-twin-caol-ila-ba/395336/': ['Evil Twin Brewing',
#   'Evil Twin Caol Ila BA'],
#  '/beer/stone-delicious-ipa--almonds-apricots/344866/': ['Stone Brewing',
#   'Stone Delicious IPA - Almonds & Apricots'],
#  '/beer/merciless-untamed-forces/212022/': ['Merciless Brewing',
#   'Merciless Untamed Forces'],
#  '/beer/wicked-weed-english-infidel/279072/': ['Wicked Weed Brewing',
#   'Wicked Weed English Infidel'],
#  '/beer/new-belgium--fat-heads-smoldering-sour/381355/': ['New Belgium Brewing Company',
#   'New Belgium / Fat Heads Smoldering Sour'],
#  '/beer/stone-imperial-russian-stout--american-oak/122652/': ['Stone Brewing',
#   'Stone Imperial Russian Stout - American Oak'],
#  '/beer/amager-for-the-love-of-mandarina/435502/': ['Amager Bryghus',
#   'Amager For The Love of Mandarina'],
#  '/beer/quaff-bros-catalina-wine-mixer/436752/': ['Quaff Bros',
#   'Quaff Bros Catalina Wine Mixer'],
#  '/beer/weiland-india-pale-ale/80911/': ['none', 'Weiland India Pale Ale'],
#  '/beer/siren--omnipollo--rick-gordon-lindqvist-nacken-white-wine-ba/280434/': ['Siren',
#   'Siren / Omnipollo / Rick Gordon Lindqvist Näcken (White Wine BA)'],
#  '/beer/trillium-heavy-mettle/282332/': ['Trillium Brewing Company',
#   'Trillium Heavy Mettle'],
#  '/beer/new-belgium-lemon-ginger-berliner-weiss/440523/': ['New Belgium Brewing Company',
#   'New Belgium Lemon Ginger Berliner Weiss'],
#  '/beer/jopen-frans-hals-bier/212137/': ['Jopen', 'Jopen Frans Hals Bier'],
#  '/beer/stone-scru-wit/418419/': ['Stone Brewing', 'Stone Scrü Wit'],
#  '/beer/sierra-nevada-beer-camp-085-altered/191273/': ['Sierra Nevada Brewing Company',
#   'Sierra Nevada Beer Camp 085: AlteRED'],
#  '/beer/de-molen-borefts-blond/32557/': ['Brouwerij de Molen',
#   'De Molen Borefts Blond'],
#  '/beer/brewdog--stone--magic-rock-magic-stone-dog/281697/': ['BrewDog',
#   'BrewDog / Stone / Magic Rock Magic Stone Dog'],
#  '/beer/new-belgium-side-trip-dry-cider/434290/': ['New Belgium Brewing Company',
#   'New Belgium Side Trip Dry Cider'],
#  '/beer/sierra-nevada-beer-camp-167-slow-clap/434977/': ['Sierra Nevada Brewing Company',
#   'Sierra Nevada Beer Camp 167: Slow Clap'],
#  '/beer/hill-farmstead-civil-disobedience-release-2/154612/': ['Hill Farmstead Brewery',
#   'Hill Farmstead Civil Disobedience (Release 2)'],
#  '/beer/wicked-weed-angel-of-darkness/382597/': ['Wicked Weed Brewing',
#   'Wicked Weed Angel of Darkness'],
#  '/beer/wicked-weed-poperinge-belgian-ipa/198629/': ['Wicked Weed Brewing',
#   'Wicked Weed Poperinge Belgian IPA'],
#  '/beer/modern-times-empty-hats/298837/': ['Modern Times Beer',
#   'Modern Times Empty Hats'],
#  '/beer/cigar-city-death-metal-rye-stout/128856/': ['Cigar City Brewing',
#   'Cigar City Death Metal Rye Stout'],
#  '/beer/trillium-scaled-way-up/409752/': ['Trillium Brewing Company',
#   'Trillium Scaled Way Up'],
#  '/beer/the-bruery-oude-tart--plums/281801/': ['The Bruery',
#   'The Bruery Oude Tart - Plums'],
#  '/beer/nogne-o--holgate-brewhouse-half-a-world-away/214858/': ['Nøgne Ø (Hansa Borg)',
#   'Nøgne Ø / Holgate Brewhouse Half A World Away'],
#  '/beer/amager-southern-peach/269247/': ['Amager Bryghus',
#   'Amager Southern Peach'],
#  '/beer/dugges-saison-de-maracuja/276770/': ['Dugges Bryggeri',
#   'Dugges Saison De Maracujá'],
#  '/beer/against-the-grain-wiggity-weeeeet/176945/': ['Against the Grain Brewery',
#   'Against the Grain Wiggity Weeeeet'],
#  '/beer/evil-twin-fire/217422/': ['none', 'Evil Twin Fire'],
#  '/beer/dugges-tasty-55/432510/': ['none', 'none'],
#  '/beer/bells-reading-ale/351797/': ['Bell\x92s Brewery', 'Bells Reading Ale'],
#  '/beer/to-ol-mochaccino-messiah/172760/': ['To Øl',
#   'To Øl Mochaccino Messiah'],
#  '/beer/mikkeller-noma-pontus/191359/': ['Mikkeller', 'Mikkeller Noma Pontus'],
#  '/beer/21st-amendment-5-south/128759/': ['21st Amendment Brewery',
#   '21st Amendment 5-South'],
#  '/beer/21st-amendment-back-in-black/95188/': ['21st Amendment Brewery',
#   '21st Amendment Back in Black'],
#  '/beer/the-bruery-mischief-1/105305/': ['The Bruery',
#   'The Bruery Mischief #1'],
#  '/beer/three-floyds-cherron/345803/': ['Three Floyds Brewing Company',
#   'Three Floyds Cherron'],
#  '/beer/the-bruery-8-maids-a-milking--candy-cap-mushrooms/364733/': ['The Bruery',
#   'The Bruery 8 Maids-A-Milking - Candy Cap Mushrooms'],
#  '/beer/avery-caffeina/298446/': ['Avery Brewing Company', 'Avery caffeinA'],
#  '/beer/stillwater-stateside-saison--french-oak-chips/118083/': ['Stillwater Artisanal',
#   'Stillwater Stateside Saison - French Oak Chips'],
#  '/beer/against-the-grain-spastic-koln/357333/': ['Against the Grain Brewery',
#   'Against the Grain Spastic Köln'],
#  '/beer/siren-calypso-berliner-weisse--citra-enigma/418854/': ['none', 'none'],
#  '/beer/siren-red-rind-ipa/211952/': ['Siren', 'Siren Red Rind IPA'],
#  '/beer/sierra-nevada--dogfish-head-life-limb--barrel-aged/130511/': ['Sierra Nevada Brewing Company',
#   'Sierra Nevada / Dogfish Head Life & Limb - Barrel Aged'],
#  '/beer/hill-farmstead-everett/126305/': ['Hill Farmstead Brewery',
#   'Hill Farmstead Everett'],
#  '/beer/boulevard-test-cranberry-orange-radler/435173/': ['Boulevard Brewing Company (Duvel-Moortgat)',
#   'Boulevard Test Cranberry Orange Radler'],
#  '/beer/wicked-weed-bless-her-heart/324874/': ['Wicked Weed Brewing',
#   'Wicked Weed Bless Her Heart'],
#  '/beer/the-bruery-toddy-barleywine/122853/': ['The Bruery',
#   'The Bruery Toddy Barleywine'],
#  '/beer/samuel-adams-13th-year-anniversary-festival-beer/95180/': ['none',
#   'Samuel Adams 13th Year Anniversary Festival Beer'],
#  '/beer/cigar-city-can-of-cranberries/377830/': ['Cigar City Brewing',
#   'Cigar City Can of Cranberries'],
#  '/beer/evil-twin-epilogue/165658/': ['Evil Twin Brewing',
#   'Evil Twin Epilogue'],
#  '/beer/brew-bus-rollin-dirty-red-ale--bourbon-pecan/390252/': ['Brew Bus Brewing',
#   'Brew Bus Rollin Dirty Red Ale - Bourbon Pecan'],
#  '/beer/cloudwater--kees-red-wine-ba-autum-fruit-custard-porter/437593/': ['Cloudwater Brew Co',
#   'Cloudwater / Kees Red Wine BA Autum Fruit Custard Porter'],
#  '/beer/ballast-point-the-salty-scotsman/378661/': ['Ballast Point Brewing Company (Constellation)',
#   'Ballast Point The Salty Scotsman'],
#  '/beer/to-ol-amnecia/170908/': ['To Øl', 'To Øl Amnecia'],
#  '/beer/brewdog-barrel-aged-albino-squid-assassin/409864/': ['BrewDog',
#   'BrewDog Barrel Aged Albino Squid Assassin'],
#  '/beer/cigar-city-brewpub-zeros-nose/312647/': ['Cigar City Brewing',
#   'Cigar City Brewpub Zeros Nose'],
#  '/beer/the-kernel-pale-ale-sac/156487/': ['The Kernel',
#   'The Kernel Pale Ale S.A.C.'],
#  '/beer/the-kernel-india-pale-ale-double-sccans/178647/': ['The Kernel',
#   'The Kernel India Pale Ale Double SCCANS'],
#  '/beer/thornbridge-otto/254480/': ['Thornbridge', 'Thornbridge Otto'],
#  '/beer/beavertown-bourbon-betty/203071/': ['none',
#   'Beavertown Bourbon Betty'],
#  '/beer/de-molen-spanning-sensatie/176707/': ['Brouwerij de Molen',
#   'De Molen Spanning & Sensatie'],
#  '/beer/prairie-twice-as-weiss/458291/': ['Prairie Artisan Ales',
#   'Prairie Twice as Weiss'],
#  '/beer/samuel-adams-latitude-48-deconstructed-ipa--zeus/143032/': ['Boston Beer Company',
#   'Samuel Adams Latitude 48 Deconstructed IPA - Zeus'],
#  '/beer/three-floyds-formorian-priestess/187982/': ['Three Floyds Brewing Company',
#   'Three Floyds Formorian Priestess'],
#  '/beer/wicked-weed-oblivion-sour-red/243825/': ['Wicked Weed Brewing',
#   'Wicked Weed Oblivion Sour Red'],
#  '/beer/wicked-weed-hibiscus-wit/224301/': ['Wicked Weed Brewing',
#   'Wicked Weed Hibiscus Wit'],
#  '/beer/to-ol-ryeght-on/364064/': ['To Øl', 'To Øl Ryeght On'],
#  '/beer/mi322os322aw-sosnowe-apa/425785/': ['Browar Fortuna',
#   'Miłosław Sosnowe APA'],
#  '/beer/de-molen-freya-thor/120814/': ['Brouwerij de Molen',
#   'De Molen Freya & Thor'],
#  '/beer/thornbridge-bayern/231514/': ['Thornbridge', 'Thornbridge Bayern'],
#  '/beer/uiltje-peer-pressure/352611/': ['Uiltje Brewing Co.',
#   'Uiltje Peer Pressure'],
#  '/beer/de-molen-vuur-vlam-soriachi-ace/135716/': ['Brouwerij de Molen',
#   'De Molen Vuur & Vlam Soriachi Ace'],
#  '/beer/buxton-wild-boar/151883/': ['Buxton', 'Buxton Wild Boar'],
#  '/beer/cigar-city-summer-session-ipa/435806/': ['Cigar City Brewing',
#   'Cigar City Summer Session IPA'],
#  '/beer/cigar-city-sugar-plum-white-winter-ale-2015/380469/': ['Cigar City Brewing',
#   'Cigar City Sugar Plum White Winter Ale (2015)'],
#  '/beer/xbeeriment-berthold-brett-reads-das-kapital/210640/': ['Xbeeriment',
#   'Xbeeriment Berthold Brett reads Das Kapital'],
#  '/beer/three-floyds-gorch-fock-helles/45534/': ['Three Floyds Brewing Company',
#   'Three Floyds Gorch Fock Helles'],
#  '/beer/samuel-adams-spring-ale/170/': ['Boston Beer Company',
#   'Samuel Adams Spring Ale'],
#  '/beer/siren-calypso-berliner-weisse--centennial-enigma/436210/': ['Siren',
#   'Siren Calypso Berliner Weisse - Centennial & Enigma'],
#  '/beer/de-molen-larie-apekool/172158/': ['Brouwerij de Molen',
#   'De Molen Larie & Apekool'],
#  '/beer/thornbridge-raven/208070/': ['none', 'Thornbridge Raven'],
#  '/beer/wicked-weed-cuvee-fumee/426762/': ['Wicked Weed Brewing',
#   'Wicked Weed Cuvee Fumee'],
#  '/beer/brewdog-raspberry-riptide/330587/': ['BrewDog',
#   'BrewDog Raspberry Riptide'],
#  '/beer/founders-barrel-aged-porter/82232/': ['Founders Brewing Company',
#   'Founders Barrel Aged Porter'],
#  '/beer/mikkeller-milf-stout/187010/': ['Mikkeller', 'Mikkeller Milf Stout'],
#  '/beer/nogne-o-god-paske-2005-2006/44810/': ['Nøgne Ø (Hansa Borg)',
#   'Nøgne Ø God Påske 2005-2006'],
#  '/beer/modern-times-pilot-batch-10-dunkelweizen/251647/': ['Modern Times Beer',
#   'Modern Times Pilot Batch #10: Dunkelweizen'],
#  '/beer/rock-brothers-high-road-ale/254170/': ['Rock Brothers Brewing Company',
#   'Rock Brothers High Road Ale'],
#  '/beer/deschutes-polaris-ipa/184026/': ['Deschutes Brewery',
#   'Deschutes Polaris IPA'],
#  '/beer/dugges-new-fusion/310062/': ['Dugges Bryggeri', 'Dugges New Fusion'],
#  '/beer/flying-dog-brewhouse-rarities-smoked-belgian-stout/381837/': ['Flying Dog Brewery',
#   'Flying Dog Brewhouse Rarities: Smoked Belgian Stout'],
#  '/beer/evil-twin-sour-power/260094/': ['Evil Twin Brewing',
#   'Evil Twin Sour Power'],
#  '/beer/cloudwater-ipa/321407/': ['Cloudwater Brew Co', 'Cloudwater IPA'],
#  '/beer/thornbridge-wye/170962/': ['Thornbridge', 'Thornbridge Wye'],
#  '/beer/to-ol-berliner-vice/421290/': ['To Øl', 'To Øl Berliner Vice'],
#  '/beer/evil-twin-erase-and-rewind-volume-2/443128/': ['Evil Twin Brewing',
#   'Evil Twin Erase and Rewind Volume 2'],
#  '/beer/three-floyds-czech-booty-kamp/198268/': ['Three Floyds Brewing Company',
#   'Three Floyds Czech Booty Kamp'],
#  '/beer/jopen-the-sinking-ship/419242/': ['Jopen', 'Jopen The Sinking Ship'],
#  '/beer/lervig-bokk/99121/': ['none', 'Lervig Bokk'],
#  '/beer/thornbridge-baize/203351/': ['Thornbridge', 'Thornbridge Baize'],
#  '/beer/crooked-stave-fertile-soil/159586/': ['Crooked Stave',
#   'Crooked Stave Fertile Soil'],
#  '/beer/de-molen-borefts-witbier/49851/': ['Brouwerij de Molen',
#   'De Molen Borefts Witbier'],
#  '/beer/nogne-o-god-paske-2015/320882/': ['Nøgne Ø (Hansa Borg)',
#   'Nøgne Ø God Påske 2015'],
#  '/beer/cigar-city-mango-chili-wheat/174481/': ['Cigar City Brewing',
#   'Cigar City Mango Chili Wheat'],
#  '/beer/the-kernel-india-pale-ale-zeus-exp-431-el-dorado-nelson-sauvin/450421/': ['The Kernel',
#   'The Kernel India Pale Ale Zeus EXP 431 El Dorado Nelson Sauvin'],
#  '/beer/evil-twin-uber-tart/172107/': ['Evil Twin Brewing',
#   'Evil Twin Über Tart'],
#  '/beer/mikkeller-sour-god/281775/': ['Mikkeller', 'Mikkeller Sour God'],
#  '/beer/bells-kalamazoo-common/109137/': ['Bell\x92s Brewery',
#   'Bells Kalamazoo Common'],
#  '/beer/hill-farmstead-everett--bourbon-barrel-aged-2014-/266073/': ['Hill Farmstead Brewery',
#   'Hill Farmstead Everett - Bourbon Barrel Aged (2014-)'],
#  '/beer/nogne-o-rod-jul/371608/': ['Nøgne Ø (Hansa Borg)', 'Nøgne Ø Rød Jul'],
#  '/beer/nogne-o-strandhogg/346721/': ['Nøgne Ø (Hansa Borg)',
#   'Nøgne Ø Strandhogg'],
#  '/beer/crooked-stave-nightmare-on-brett-laws-whiskey/389448/': ['Crooked Stave',
#   'Crooked Stave Nightmare on Brett (Laws Whiskey)'],
#  '/beer/mikkeller-chill-pils-orange-juice/249900/': ['Mikkeller',
#   'Mikkeller Chill Pils (Orange Juice)'],
#  '/beer/mikkeller-trippelbock/150389/': ['none', 'Mikkeller Trippelbock'],
#  '/beer/brew-by-numbers-05-14-india-pale-ale--citra-summit/400178/': ['Brew By Numbers',
#   'Brew By Numbers 05/14 India Pale Ale - Citra Summit'],
#  '/beer/cigar-city-penultimate-push/150988/': ['Cigar City Brewing',
#   'Cigar City Penultimate Push'],
#  '/beer/wieckse-witte-00/142754/': ['Heineken Nederland',
#   'Wieckse Witte 0,0%'],
#  '/beer/brewdog-paradox-islay-batch-008/79408/': ['BrewDog',
#   'BrewDog Paradox Islay (Batch 008)'],
#  '/beer/the-kernel-india-pale-ale-citra-galaxy-mosaic/260770/': ['The Kernel',
#   'The Kernel India Pale Ale Citra Galaxy Mosaic'],
#  '/beer/deschutes-long-shadow-black-ipa/113866/': ['Deschutes Brewery',
#   'Deschutes Long Shadow Black IPA'],
#  '/beer/three-floyds-black-sun-stout--bourbon-barrel/67677/': ['Three Floyds Brewing Company',
#   'Three Floyds Black Sun Stout - Bourbon Barrel'],
#  '/beer/mikkeller-spontancranberry/147187/': ['Mikkeller',
#   'Mikkeller SpontanCranberry'],
#  '/beer/new-belgium-read-my-lips-belgian-strong-golden-ale/459755/': ['New Belgium Brewing Company',
#   'New Belgium Read My Lips Belgian Strong Golden Ale'],
#  '/beer/pohjala-crema/394579/': ['Põhjala', 'Põhjala Crema'],
#  '/beer/kalamazoo-american-wheat/86970/': ['Bell\x92s Brewery',
#   'Kalamazoo American Wheat'],
#  '/beer/cigar-city-hunahpu146s-imperial-stout--chocolate-peanut-butter/402122/': ['Cigar City Brewing',
#   'Cigar City Hunahpus Imperial Stout - Chocolate Peanut Butter'],
#  '/beer/amager-bybi-honning-ol/192852/': ['Amager Bryghus',
#   'Amager Bybi Honning Øl'],
#  '/beer/wicked-weed-pear-bear/262981/': ['Wicked Weed Brewing',
#   'Wicked Weed Pear Bear'],
#  '/beer/stillwater--arizona-wilderness-stillwater-is-nothing-big-bunny-is-everything/413679/': ['Stillwater Artisanal',
#   'Stillwater / Arizona Wilderness Stillwater Is Nothing Big Bunny Is Everything'],
#  '/beer/evil-twin-aviary-five/207168/': ['Evil Twin Brewing',
#   'Evil Twin Aviary Five'],
#  '/beer/mikkeller-beer-geek-vs-george-ba-calvados/301788/': ['Mikkeller',
#   'Mikkeller Beer Geek vs George BA Calvados'],
#  '/beer/cloudwater-winter-range--dr-rudi-lager/386657/': ['Cloudwater Brew Co',
#   'Cloudwater Winter Range - Dr Rudi Lager'],
#  '/beer/against-the-grain--de-molen-bo-luke-rosemary-mint/287150/': ['Against the Grain Brewery',
#   'Against the Grain / De Molen Bo & Luke (Rosemary & Mint)'],
#  '/beer/cigar-city-surry-hills/315167/': ['Cigar City Brewing',
#   'Cigar City Surry Hills'],
#  '/beer/amager--garrison-canadian-winter/199506/': ['Amager Bryghus',
#   'Amager / Garrison Canadian Winter'],
#  '/beer/mikkeller-spontanhibiscus/300611/': ['Mikkeller',
#   'Mikkeller SpontanHibiscus'],
#  '/beer/bells-bourbon-barrel-aged-expedition-stout/423017/': ['Bell\x92s Brewery',
#   'Bells Bourbon Barrel-Aged Expedition Stout'],
#  '/beer/brewdog-ipa-is-dead--citra/138896/': ['BrewDog',
#   'BrewDog IPA Is Dead - Citra'],
#  '/beer/flying-dog-brewhouse-rarities-berliner-weisse/437293/': ['none',
#   'Flying Dog Brewhouse Rarities: Berliner Weisse'],
#  '/beer/mikkeller-mastodon-mother-puncher/344025/': ['Mikkeller',
#   'Mikkeller Mastodon Mother Puncher'],
#  '/beer/stone-farking-wheaton-w00tstout-20/277481/': ['none',
#   'Stone Farking Wheaton w00tstout 2.0'],
#  '/beer/three-floyds-alpha-naught-2008/92046/': ['Three Floyds Brewing Company',
#   'Three Floyds Alpha Naught (2008)'],
#  '/beer/cigar-city-jai-alai-ipa--ginger-peach/247312/': ['Cigar City Brewing',
#   'Cigar City Jai Alai IPA - Ginger Peach'],
#  '/beer/hill-farmstead-twilight-of-the-idols/132114/': ['Hill Farmstead Brewery',
#   'Hill Farmstead Twilight of the Idols'],
#  '/beer/deschutes-hallertauer-pilsner/221909/': ['Deschutes Brewery',
#   'Deschutes Hallertauer Pilsner'],
#  '/beer/jopen-zwarte-zee/419241/': ['Jopen', 'Jopen Zwarte Zee'],
#  '/beer/heilemans-old-style-la-gold/26180/': ['Pabst Brewing Company',
#   'Heilemans Old Style L.A. Gold'],
#  '/beer/the-kernel-export-india-porter-amarillo-chinook-sticklebract/414753/': ['none',
#   'The Kernel Export India Porter Amarillo Chinook Sticklebract'],
#  '/beer/wieckse-brut/23155/': ['Heineken Nederland', 'Wieckse Brut'],
#  '/beer/amager-a-drop-of-lemon/357997/': ['Amager Bryghus',
# ...
#   'Oskar Blues Ten FIDY - Apple Brandy Barrel'],
#  '/beer/oskar-blues-old-double-bagger-odb/116637/': ['Oskar Blues Brewery',
#   'Oskar Blues Old Double Bagger (ODB)'],
#  '/beer/the-bruery-smoking-wood--coffee/292194/': ['The Bruery',
#   'The Bruery Smoking Wood - Coffee'],
#  '/beer/against-the-grain-galangal-action/185385/': ['Against the Grain Brewery',
#   'Against the Grain Galangal Action'],
#  '/beer/cigar-city-brewpub-ryetious-dude/395807/': ['Cigar City Brewing',
#   'Cigar City Brewpub Ryetious Dude'],
#  '/beer/cigar-city-smash-citra/402793/': ['Cigar City Brewing',
#   'Cigar City SMaSH Citra'],
#  '/beer/against-the-grain-wakatube/200462/': ['Against the Grain Brewery',
#   'Against the Grain Wakatube'],
#  '/beer/petes-uptown-blonde/103572/': ['none', 'Petes Uptown Blonde'],
#  '/beer/thornbridge-bear-state/189912/': ['none', 'Thornbridge Bear State'],
#  '/beer/evil-twin-fitzroy-hipster-ale/268072/': ['Evil Twin Brewing',
#   'Evil Twin Fitzroy Hipster Ale'],
#  '/beer/wicked-weed-new-hop-aesthetic/382911/': ['Wicked Weed Brewing',
#   'Wicked Weed New Hop Aesthetic'],
#  '/beer/the-bruery-hottenroth-berliner-weisse/355486/': ['none',
#   'The Bruery Hottenroth Berliner Weisse'],
#  '/beer/to-ol-sur-maelk/252204/': ['To Øl', 'To Øl Sur Mælk'],
#  '/beer/cigar-city-white-oak-chocolate-robust-porter/174860/': ['Cigar City Brewing',
#   'Cigar City White Oak Chocolate Robust Porter'],
#  '/beer/new-belgium-two-cherry-ale/9219/': ['New Belgium Brewing Company',
#   'New Belgium Two Cherry Ale'],
#  '/beer/ballast-point-victory-at-sea--chai/382207/': ['Ballast Point Brewing Company (Constellation)',
#   'Ballast Point Victory at Sea - Chai'],
#  '/beer/de-molen-koetjes-kalfjes-milk-stout/186548/': ['Brouwerij de Molen',
#   'De Molen Koetjes & Kalfjes Milk Stout'],
#  '/beer/kees--laugar-brewed-with-friends-2/406932/': ['Brouwerij Kees',
#   'Kees / Laugar Brewed with Friends #2'],
#  '/beer/the-kernel-export-india-porter-cascase-apollo-amarilo/366303/': ['none',
#   'The Kernel Export India Porter Cascase Apollo Amarilo'],
#  '/beer/hill-farmstead-earl-cocoa-nibs-vanilla/421240/': ['Hill Farmstead Brewery',
#   'Hill Farmstead Earl (Cocoa Nibs & Vanilla)'],
#  '/beer/mikkeller-garage-fridge/332768/': ['Mikkeller',
#   'Mikkeller Garage Fridge'],
#  '/beer/oskar-blues-blackberry-alt-itude/100369/': ['Oskar Blues Brewery',
#   'Oskar Blues Blackberry Alt-itude'],
#  '/beer/dugges-coconut-grove/371901/': ['Dugges Bryggeri',
#   'Dugges Coconut Grove'],
#  '/beer/deschutes-firewood/75844/': ['Deschutes Brewery',
#   'Deschutes Firewood'],
#  '/beer/founders-bad-habit-quad/31861/': ['Founders Brewing Company',
#   'Founders Bad Habit Quad'],
#  '/beer/the-bruery-safron-mischief/140141/': ['The Bruery',
#   'The Bruery Safron Mischief'],
#  '/beer/stillwater-red-33/126307/': ['Stillwater Artisanal',
#   'Stillwater Red 33'],
#  '/beer/to-ol-special-borefts-braggot-forca-victory-xtra-ekstra-edition-082/231308/': ['none',
#   'To Øl Special Borefts Braggot Forca Victory Xtra Ekstra Edition 0.8.2'],
#  '/beer/mikkeller-kihoskh-fall-thorsth/132073/': ['Mikkeller',
#   'Mikkeller Kihoskh Fall Thørsth'],
#  '/beer/mikkeller-santas-little-helper-2012-barrel-aged-cognac-edition/233358/': ['Mikkeller',
#   'Mikkeller Santas Little Helper 2012 (Barrel Aged Cognac Edition)'],
#  '/beer/de-molen-klap-van-de-molen-2012-2013/204063/': ['Brouwerij de Molen',
#   'De Molen Klap Van De Molen 2012-2013'],
#  '/beer/mikkeller-spontanmandarin/227968/': ['Mikkeller',
#   'Mikkeller SpontanMandarin'],
#  '/beer/de-molen-bommen-granaten-pedro-ximenez-ba/319659/': ['Brouwerij de Molen',
#   'De Molen Bommen & Granaten (Pedro Ximenez BA)'],
#  '/beer/cigar-city-monsieur-zhukovs-biere-de-stout/150989/': ['Cigar City Brewing',
#   'Cigar City Monsieur Zhukovs Biere de Stout'],
#  '/beer/against-the-grain-finnishing-school/427240/': ['Against the Grain Brewery',
#   'Against the Grain Finnishing School'],
#  '/beer/firestone-walker-luponic-distortion-2011-version/153699/': ['Firestone Walker Brewing (Duvel Moortgat)',
#   'Firestone Walker Luponic Distortion (2011 Version)'],
#  '/beer/de-molen--flying-dog-bat-out-of-hell-oak-aged-version/135623/': ['Brouwerij de Molen',
#   'De Molen / Flying Dog Bat Out Of Hell Oak Aged Version'],
#  '/beer/jopen-populus-6921-blond-eiken/419846/': ['Jopen',
#   'Jopen  Populus 6921 Blond Eiken'],
#  '/beer/brewdog-v2009/100602/': ['none', 'BrewDog V2009'],
#  '/beer/brewdog-5-am-saint/107269/': ['BrewDog', 'BrewDog 5 A.M. Saint'],
#  '/beer/evil-twin--beavertown-xxx/339759/': ['Evil Twin Brewing',
#   'Evil Twin / Beavertown XXX'],
#  '/beer/cigar-city-wingtip-wheat/317618/': ['Cigar City Brewing',
#   'Cigar City Wingtip Wheat'],
#  '/beer/evil-twin-mystery-stout/166219/': ['Evil Twin Brewing',
#   'Evil Twin Mystery Stout'],
#  '/beer/cigar-city-peach-lager/200629/': ['Cigar City Brewing',
#   'Cigar City Peach Lager'],
#  '/beer/boulevard-smokestack-series-reverb-imperial-pilsner/183371/': ['Boulevard Brewing Company (Duvel-Moortgat)',
#   'Boulevard Smokestack Series: Reverb Imperial Pilsner'],
#  '/beer/modern-times-sleep-dealer/408112/': ['Modern Times Beer',
#   'Modern Times Sleep Dealer'],
#  '/beer/mikkeller-hop-burn-high/161167/': ['Mikkeller',
#   'Mikkeller Hop Burn High'],
#  '/beer/de-molen--gadds-live-long-prosper/254343/': ['Brouwerij de Molen',
#   'De Molen / Gadds Live Long & Prosper'],
#  '/beer/samuel-adams-16th-anniversary-festival-ale/155331/': ['Boston Beer Company',
#   'Samuel Adams 16th Anniversary Festival Ale'],
#  '/beer/evil-twin-licorice-lovers-jesus-chili-edition/189203/': ['Evil Twin Brewing',
#   'Evil Twin Licorice Lovers Jesus (Chili Edition)'],
#  '/beer/the-kernel-export-india-porter-apollo/184319/': ['The Kernel',
#   'The Kernel Export India Porter Apollo'],
#  '/beer/brew-by-numbers-17-07-table-saison--huell-melon/449748/': ['Brew By Numbers',
#   'Brew By Numbers 17/07 Table Saison - Huell Melon'],
#  '/beer/buxton--omnipollo-lemon-meringue-ice-cream-pie/447868/': ['Buxton',
#   'Buxton / Omnipollo Lemon Meringue Ice Cream Pie'],
#  '/beer/ballast-point-black-marlin-porter--blackberry-oak/95068/': ['Ballast Point Brewing Company (Constellation)',
#   'Ballast Point Black Marlin Porter - Blackberry & Oak'],
#  '/beer/mikkeller-crooked-moon-tattoo-dipa/194686/': ['Mikkeller',
#   'Mikkeller Crooked Moon Tattoo dIPA'],
#  '/beer/avery-out-of-mind-stout/230917/': ['none', 'Avery Out of Mind Stout'],
#  '/beer/flying-dog-extra-special-double-dog-pale-ale/79484/': ['Flying Dog Brewery',
#   'Flying Dog Extra Special Double Dog Pale Ale'],
#  '/beer/21st-amendment-blind-lust/69382/': ['21st Amendment Brewery',
#   '21st Amendment Blind Lust'],
#  '/beer/cloudwater-dipa--v6/441009/': ['Cloudwater Brew Co',
#   'Cloudwater DIPA - v6'],
#  '/beer/sierra-nevada-extra-special-pale/65551/': ['none',
#   'Sierra Nevada Extra Special Pale'],
#  '/beer/against-the-grain-bhretto-blaster/322781/': ['Against the Grain Brewery',
#   'Against the Grain Bhretto Blaster'],
#  '/beer/dugges--beerbliotek-raisin-hell/311346/': ['Dugges Bryggeri',
#   'Dugges / Beerbliotek Raisin Hell'],
#  '/beer/thornbridge-kastor/58416/': ['Thornbridge', 'Thornbridge Kastor'],
#  '/beer/prairie-bomb/215531/': ['Prairie Artisan Ales', 'Prairie Bomb!'],
#  '/beer/cloudwater-spring-summer-2016-epic-lager/399418/': ['Cloudwater Brew Co',
#   'Cloudwater Spring Summer 2016 Epic Lager'],
#  '/beer/the-kernel-pale-ale-pacific-jade/156502/': ['The Kernel',
#   'The Kernel Pale Ale Pacific Jade'],
#  '/beer/ballast-point-brown-fairy/406352/': ['Ballast Point Brewing Company (Constellation)',
#   'Ballast Point Brown Fairy'],
#  '/beer/brewdog-six-impossible-things/230512/': ['BrewDog',
#   'BrewDog Six Impossible Things'],
#  '/beer/the-bruery-hot-sauce-barrel-aged-black-tuesday/290980/': ['The Bruery',
#   'The Bruery Hot Sauce Barrel Aged Black Tuesday'],
#  '/beer/against-the-grain-kummerspeck/365171/': ['Against the Grain Brewery',
#   'Against the Grain Kümmerspeck'],
#  '/beer/new-belgium--wicked-weed-brett-ipa/268314/': ['New Belgium Brewing Company',
#   'New Belgium / Wicked Weed Brett IPA'],
#  '/beer/lowlander-beer-white-ale/352558/': ['Lowlander Beer',
#   'Lowlander Beer White Ale'],
#  '/beer/blue-moon-abbey-ale/2575/': ['Coors Brewing Company (MillerCoors)',
#   'Blue Moon Abbey Ale'],
#  '/beer/deschutes-mt-saint-helens-keller-bier/57286/': ['Deschutes Brewery',
#   'Deschutes Mt Saint Helens Keller Bier'],
#  '/beer/sierra-nevada-kellerweis-hefeweizen/100383/': ['Sierra Nevada Brewing Company',
#   'Sierra Nevada Kellerweis Hefeweizen'],
#  '/beer/samuel-adams-sample-b--rye-pale-ale/136995/': ['none', 'none'],
#  '/beer/pohjala-valge-laev-2015-/321818/': ['Põhjala',
#   'Põhjala Valge Laev (2015-)'],
#  '/beer/new-belgium-love--felix-apple/365253/': ['New Belgium Brewing Company',
#   'New Belgium Love - Felix Apple'],
#  '/beer/mikkeller-kihoskh-juleol/368926/': ['Mikkeller',
#   'Mikkeller Kihoskh Juleøl'],
#  '/beer/lagunitas-ginger-snap-pils/444170/': ['Lagunitas Brewing Company (Heineken)',
#   'Lagunitas Ginger Snap Pils'],
#  '/beer/third-coast-old-ale--quince/287722/': ['none', 'none'],
#  '/beer/mikkeller-x-calvados-barrel-aged-barley-wine/102842/': ['Mikkeller',
#   'Mikkeller X Calvados Barrel Aged Barley Wine'],
#  '/beer/the-bruery-side-saddle-that-bean/439619/': ['The Bruery',
#   'The Bruery Side Saddle That Bean'],
#  '/beer/cigar-city-white-oak-key-lime-ipa/283826/': ['Cigar City Brewing',
#   'Cigar City White Oak Key Lime IPA'],
#  '/beer/the-bruery-arbre--alligator-char/351855/': ['The Bruery',
#   'The Bruery Arbre - Alligator Char'],
#  '/beer/mikkeller-cascade-ipa/51095/': ['none', 'Mikkeller Cascade IPA'],
#  '/beer/siren-i-need-a-vacation-keg-25/230338/': ['Siren',
#   'Siren I Need A Vacation (Keg 2.5%)'],
#  '/beer/modern-times-ice-lime/453445/': ['Modern Times Beer',
#   'Modern Times Ice Lime'],
#  '/beer/mikkeller-raspberries-cream/324475/': ['Mikkeller',
#   'Mikkeller Raspberries & Cream'],
#  '/beer/cigar-city-raspberry-berliner-weisse/219575/': ['Cigar City Brewing',
#   'Cigar City Raspberry Berliner Weisse'],
#  '/beer/crooked-stave-petite-sour/171076/': ['Crooked Stave',
#   'Crooked Stave Petite Sour'],
#  '/beer/stone-mocha-ipa/335546/': ['Stone Brewing', 'Stone Mocha IPA'],
#  '/beer/stone-ipa--styrian-wolf/456422/': ['Stone Brewing',
#   'Stone IPA - Styrian Wolf'],
#  '/beer/wicked-weed-poperinge-saison/335303/': ['Wicked Weed Brewing',
#   'Wicked Weed Poperinge Saison'],
#  '/beer/bells-dagger-stout--bourbon-barrel/232225/': ['Bell\x92s Brewery',
#   'Bells Dagger Stout - Bourbon Barrel'],
#  '/beer/the-bruery-melange-1/92687/': ['none', 'The Bruery Melange #1'],
#  '/beer/wicked-weed-relenting-and-dubbeled/308457/': ['Wicked Weed Brewing',
#   'Wicked Weed Relenting and Dubbeled'],
#  '/beer/new-belgium-whiskey-barrel-aged-blackberry-barley-wine/376806/': ['New Belgium Brewing Company',
#   'New Belgium Whiskey Barrel Aged Blackberry Barley Wine'],
#  '/beer/siren--omnipollo--rick-gordon-lindqvist-nacken/228760/': ['Siren',
#   'Siren / Omnipollo / Rick Gordon Lindqvist Näcken'],
#  '/beer/flying-dog-belgian-style-pale-ale/372756/': ['Flying Dog Brewery',
#   'Flying Dog Belgian Style Pale Ale'],
#  '/beer/the-bruery-speculoos/421406/': ['The Bruery', 'The Bruery Speculoos'],
#  '/beer/avery-tweak/167980/': ['Avery Brewing Company', 'Avery Tweak'],
#  '/beer/three-floyds-nite-wolf/299510/': ['Three Floyds Brewing Company',
#   'Three Floyds Nite Wolf'],
#  '/beer/ballast-point-victory-at-sea--crunchberry/236465/': ['none',
#   'Ballast Point Victory at Sea - Crunchberry'],
#  '/beer/three-floyds-secret-sub-lair/280042/': ['Three Floyds Brewing Company',
#   'Three Floyds Secret Sub Lair'],
#  '/beer/thornbridge-julius/108751/': ['Thornbridge', 'Thornbridge Julius'],
#  '/beer/mikkeller-santas-little-helper-2012-barrel-aged-grand-marnier-edition/234573/': ['Mikkeller',
#   'Mikkeller Santas Little Helper 2012 (Barrel Aged Grand Marnier Edition)'],
#  '/beer/deschutes-fresh-hopped-helles/446171/': ['Deschutes Brewery',
#   'Deschutes Fresh Hopped Helles'],
#  '/beer/ideal-azabache/204945/': ['Grupo Modelo (Corona)', 'Ideal Azabache'],
#  '/beer/founders-azacca-ipa--oak-chips/396684/': ['Founders Brewing Company',
#   'Founders Azacca IPA - Oak Chips'],
#  '/beer/evil-twin-soft-dookie/127182/': ['Evil Twin Brewing',
#   'Evil Twin Soft Dookie'],
#  '/beer/firestone-walker-wild-passion-stout/224429/': ['Firestone Walker Brewing (Duvel Moortgat)',
#   'Firestone Walker Wild Passion Stout'],
#  '/beer/sierra-nevada-beer-camp-140-close-call-kolsch/334557/': ['Sierra Nevada Brewing Company',
#   'Sierra Nevada Beer Camp 140: Close Call Kölsch'],
#  '/beer/mikkeller-single-hop-mosaic-ipa/315598/': ['Mikkeller',
#   'Mikkeller Single Hop Mosaic IPA'],
#  '/beer/de-molen-spanning-sensatie-whiskey-barrel/363628/': ['Brouwerij de Molen',
#   'De Molen Spanning & Sensatie (Whiskey Barrel)'],
#  '/beer/avery-eremita-ix/381375/': ['Avery Brewing Company',
#   'Avery Eremita IX'],
#  '/beer/sierra-nevada--russian-river-audition-belgian-style-blonde/265012/': ['none',
#   'Sierra Nevada / Russian River Audition Belgian-Style Blonde'],
#  '/beer/emelisse-witbier/56628/': ['Brouwerij Emelisse', 'Emelisse Witbier'],
#  '/beer/siren-salted-caramel-shattered-dream/319409/': ['Siren',
#   'Siren Salted Caramel Shattered Dream'],
#  '/beer/beavertown-beaver-blend-black-betty-and-8-ball/219344/': ['Beavertown',
#   'Beavertown Beaver Blend (Black Betty and 8 Ball)'],
#  '/beer/stone-ipa--raspberry-jasmine-lime-chili-mango/296246/': ['Stone Brewing',
#   'Stone IPA - Raspberry, Jasmine, Lime, Chili & Mango'],
#  '/beer/ballast-point-north-star-ipa/160927/': ['none',
#   'Ballast Point North Star IPA'],
#  '/beer/modern-times-black-house--coconut/229058/': ['Modern Times Beer',
#   'Modern Times Black House - Coconut'],
#  '/beer/lagunitas-minnesota-fusion-15/230551/': ['none',
#   'Lagunitas Minnesota Fusion 15'],
#  '/beer/lagunitas-fusion-ix/180099/': ['Lagunitas Brewing Company (Heineken)',
#   'Lagunitas Fusion IX'],
#  '/beer/de-molen-rye-ipa-simcoe/215288/': ['Brouwerij de Molen',
#   'De Molen Rye IPA Simcoe'],
#  '/beer/cigar-city-cognac-barrel-aged-imperial-sweet-stout/188057/': ['Cigar City Brewing',
#   'Cigar City Cognac Barrel-Aged Imperial Sweet Stout'],
#  '/beer/magic-rock--cigar-city-cigarro-roja-magica/361134/': ['Magic Rock Brewing',
#   'Magic Rock / Cigar City Cigarro Roja Magica'],
#  '/beer/the-kernel-london-porter/124835/': ['The Kernel',
#   'The Kernel London Porter'],
#  '/beer/ballast-point-rd-north-bank-bitter/274696/': ['Ballast Point Brewing Company (Constellation)',
#   'Ballast Point R&D North Bank Bitter'],
#  '/beer/cigar-city-kumquat-amarillo-wheat-ale/157249/': ['Cigar City Brewing',
#   'Cigar City Kumquat Amarillo Wheat Ale'],
#  '/beer/brewski-herr-hemlig/297539/': ['Brewski', 'Brewski Herr Hemlig'],
#  '/beer/bells-oberon-ale/3211/': ['Bell\x92s Brewery', 'Bells Oberon Ale'],
#  '/beer/bells-consecrator-doppelbock--coffee/232236/': ['Bell\x92s Brewery',
#   'Bells Consecrator Doppelbock - Coffee'],
#  '/beer/uiltje--beer-cider-india-wheat-cider/371801/': ['Uiltje Brewing Co.',
#   'Uiltje / Beer Cider India Wheat Cider'],
#  '/beer/the-kernel-pale-ale-citra/139682/': ['The Kernel',
#   'The Kernel Pale Ale Citra'],
#  '/beer/jopen-surprise-box/388276/': ['Jopen', 'Jopen Surprise Box'],
#  '/beer/bells-mead-ii/99793/': ['Bell\x92s Brewery', 'Bells Mead II'],
#  '/beer/samuel-adams-old-kentucky/190397/': ['Boston Beer Company',
#   'Samuel Adams Old Kentucky'],
#  '/beer/pohjala--norway-brewing-co-batch-zero/333630/': ['Põhjala',
#   'Põhjala / Norway Brewing Co. Batch Zero'],
#  '/beer/amager-the-sinner-series-lust/145782/': ['Amager Bryghus',
#   'Amager The Sinner Series Lust'],
#  '/beer/nogne-o-dark-horizon-first-edition/71077/': ['Nøgne Ø (Hansa Borg)',
#   'Nøgne Ø Dark Horizon First Edition'],
#  '/beer/mikkeller-single-hop-chinook-ipa/116154/': ['Mikkeller',
#   'Mikkeller Single Hop Chinook IPA'],
#  '/beer/avery-preachin-to-the-choir/100675/': ['Avery Brewing Company',
#   'Avery Preachin To The Choir'],
#  '/beer/lagunitas-sirius-ale/31622/': ['Lagunitas Brewing Company (Heineken)',
#   'Lagunitas Sirius Ale'],
#  '/beer/ice-man/9203/': ['Pabst Brewing Company', 'Ice Man'],
#  '/beer/de-molen-hel-verdoemenis-jim-beam-ba/363247/': ['Brouwerij de Molen',
#   'De Molen Hel & Verdoemenis Jim Beam BA'],
#  ...}

# %%
for c in coll.find():
    coll.update({'_id':c['_id']}, { '$set': {'content': {'k' : 'v','b': 'c'}}})

# %%
f = open('../data/brewery_hrefs.json')

# %%
j = json.loads(f.read())

# %%
brewer_list = [b.split('/brewers/')[1].split('/')[0].replace('-',' ') for b in j]

# %%
brewer_list = [b.replace('-',' ') for b in brewer_list]

# %%
from fuzzywuzzy import fuzz
# Out:
# /home/ubuntu/anaconda3/lib/python3.5/site-packages/fuzzywuzzy/fuzz.py:35: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
for b in brewer_list:    
    print(fuzz.ratio(b, 'sierra nevada brew'))
# Out:
# 22
# 52
# 32
# 17
# 40
# 9
# 77
# 29
# 39
# 39
# 33
# 31
# 16
# 7
# 35
# 37
# 29
# 31
# 23
# 17
# 36
# 50
# 20
# 35
# 32
# 21
# 19
# 36
# 34
# 49
# 19
# 31
# 44
# 27
# 21
# 30
# 37
# 8
# 40
# 31
# 43
# 44
# 39
# 35
# 47
# 24
# 32
# 34
# 17
# 39

# %%
brewer_list
# Out:
# ['mikkeller',
#  'stone brewing',
#  'brewdog',
#  'brouwerij de molen',
#  'evil twin brewing',
#  'to ol',
#  'sierra nevada brewing company',
#  'trillium brewing company',
#  'cloudwater brew co',
#  'bells brewery',
#  'founders brewing company',
#  'amager bryghus',
#  'pohjala',
#  'omnipollo',
#  'siren',
#  'lervig aktiebryggeri',
#  'the kernel',
#  'lagunitas brewing company heineken',
#  'ballast point brewing company constellation',
#  'jopen',
#  'avery brewing company',
#  'hill farmstead brewery',
#  'browar pinta',
#  'firestone walker brewing duvel moortgat',
#  'crooked stave',
#  'beavertown',
#  'brouwerij kees',
#  'the bruery',
#  'deschutes brewery',
#  'oskar blues brewery',
#  'browar fortuna',
#  'boulevard brewing company duvel moortgat',
#  'flying dog brewery',
#  'boston beer company',
#  'prairie artisan ales',
#  'dugges bryggeri',
#  'stillwater artisanal',
#  'buxton',
#  'modern times beer',
#  'new belgium brewing company',
#  'wicked weed brewing',
#  'cigar city brewing',
#  'magic rock brewing',
#  'three floyds brewing company',
#  'against the grain brewery',
#  'brew by numbers',
#  'brewski',
#  'thornbridge',
#  'brouwerij emelisse',
#  'nogne o hansa borg']
